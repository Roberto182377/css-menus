# %% [markdown]
# <a href="https://colab.research.google.com/github/Roberto182377/css-menus/blob/main/MineriaDeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Minería de Datos

# %% [markdown]
# ##Primer  Parcial

# %% [markdown]
# ###Introducción

# %% [markdown]
# ####Conceptos

# %% [markdown]
# Minería de Datos:
# La minería de datos se puede considerar

# %% [markdown]
# ####Ciencia de Datos
